# %% [markdown]
# # Submission Notes

# %% [markdown]
# ## Initial Claude prompt
#
# Hi Claude, it is a new month and that means a new Kaggle competition.  We are working on "https://www.kaggle.com/competitions/playground-series-s6e2/overview" and the data is already download into @archive/  I have already started work on the code with notes in @submission_notes.ipynb and the best file so far is @xgboost.ipynb .  Your job is to help me learn how I can improve and get a competitive score.  Understanding and experimentation are more important that winning right now.  Do not provide all of the code unless I explicitly ask.  Do not add/modify .ipynb files directly with my permission.  Everything runs inside of docker.  Keep running notes about what have learned, what we tried, and what is still yet to try.  Save that in @exploration_options.md which we will refer to as 'md'.  Ask if you need clarification.

# %%
from common import *

# %%
find_last_submission_file()
# Out:
# './archive/submission_19.csv'

# %% [markdown]
# | Submission | Notes | CV | LB |
# |-------------------|-------------------|-------------------|-------------------|
# | submission_01.csv | simple linear classifier | 0.88059 | 0.87710 |
# | submission_02.csv | simple random foreset | 0.99996 | 0.87472 |
# | submission_03.csv | simple XGBoost | 0.89007 | 0.88359 |
# | submission_04.csv | blender with XGBoost | 0.8775 | 0.88209 |
# | submission_05.csv | forum pointed out to use predict_proba instead of predict, basic XGBoost | 0.95786 | 0.95274 |
# | submission_06.csv | generating lots of new features | 0.95943 | 0.95228 |
# | submission_07.csv | picking only top 3 of pairwise features | 0.95795 | 0.95289 |
# | submission_08.csv | bringing 2000 estimators to the party |0.97715  | 0.94660 |
# | submission_09.csv | adding early stopping | 0.95688 | 0.95291 |
# | submission_10.csv | running on my MBP gave a better CV, not sure why | 0.95705 |  0.95290 |
# | submission_11.csv | add 4th pairwise feature | 0.95719 | 0.95285 |
# | submission_12.csv | removing some features | 0.95731 | 0.95285 |
# | submission_13.csv | removing pairwise feature | |  0.95281 |
# | submission_14.csv | eliminating changes, back to my best so far | 0.95692 | 0.95291 |
# | submission_15.csv | added some polynomial features | 0.95681 | 0.95292 |
# | submission_16.csv | added multiplication of low features, did not help | 0.95662 | 0.95257 |
# | submission_17.csv | same as submission_15 | 0.95684 | 0.95292 |
# | submission_18.csv | adding lr_preds as a feature | 0.95691 | 0.95289 |
# | submission_19.csv | tried treating thallium and chest_pain_type as categoricals | 0.95746 | 0.95276 |
# | submission_20.csv | tried again removing interactions with thallium and chest_pain_type | 0.95675 | 0.95288 |
# | submission_21.csv | back to submission_17.csv, added st_depression interactions | 0.95671 | 0.95268 |
# | submission_22.csv | trying more st_depression interactions | 0.95680 | 0.95287 |
# | submission_23.csv | removing low import features (polynomials) | 0.95688 | 0.95291 |
# | submission_24.csv | moving features around | 0.95703 | 0.95291 |
# | submission_25.csv | just trying combinations | 0.95735 | 0.95289 |
# | submission_26.csv | just running on workstation, basically the same | 0.95702 | 0.95288 |
# | submission_27.csv | hyperparam searching, ended up worse than default | 0.95608 | 0.94992 |
# | submission_28.csv | the is some juice to squeeze by one-hot encoding thallium and chest_pain_type | 0.95728 | 0.95296 |
# | submission_29.csv |
