# %% [markdown]
# # Predicting Heart Disease
#
# Link to Competittion: https://www.kaggle.com/competitions/playground-series-s6e2/overview

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt

matplotlib.rcParams['figure.figsize'] = (10, 5)

import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', 100)

import xgboost as xgb
from xgboost import XGBClassifier

from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold, RandomizedSearchCV, train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import auc, accuracy_score, mean_squared_error, classification_report, roc_auc_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_auc_score
from sklearn.tree import plot_tree

from pytabkit import RealMLP_TD_Classifier

from common import *

# %%
from platform import python_version
print('python: ', python_version())
print('pandas: ', pd.__version__)
print('numpy: ', np.__version__)
import matplotlib
print('matplotlib: ', matplotlib.__version__)
print('seaborn: ', sns.__version__)
import sklearn
print('sklearn: ', sklearn.__version__)
print('xgboost: ', xgb.__version__)
# Out:
# python:  3.12.3
# pandas:  2.3.3
# numpy:  2.2.6
# matplotlib:  3.10.8
# seaborn:  0.13.2
# sklearn:  1.8.0
# xgboost:  3.1.3

# %% [markdown]
# ## Load data

# %%
orig_train_df = pd.read_csv('archive/train.csv')
orig_test_df = pd.read_csv('archive/test.csv')

# %% [markdown]
# ## Call the pipeline

# %%
train_df = (orig_train_df
          .pipe(copy_data)
          .pipe(clean_data)
          # .pipe(remove_outliers)
          # .pipe(remove_duplicates)
          .pipe(make_new_features)
          # .pipe(encode_all_the_things)
          # .pipe(fill_nas)
           )

# %%
test_df = (orig_test_df
          .pipe(copy_data)
          .pipe(clean_data)
          # .pipe(remove_outliers)
          # .pipe(remove_duplicates)
          .pipe(make_new_features)
          # .pipe(encode_all_the_things)
          # .pipe(fill_nas)
           )

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630000 entries, 0 to 629999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   age                      630000 non-null  int64
#  1   sex                      630000 non-null  int64
#  2   chest_pain_type          630000 non-null  int64
#  3   bp                       630000 non-null  int64
#  4   cholesterol              630000 non-null  int64
#  5   fbs_over_120             630000 non-null  int64
#  6   ekg_results              630000 non-null  int64
#  7   max_hr                   630000 non-null  int64
#  8   exercise_angina          630000 non-null  int64
#  9   st_depression            630000 non-null  float64
#  10  slope_of_st              630000 non-null  int64
#  11  number_of_vessels_fluro  630000 non-null  int64
#  12  thallium                 630000 non-null  int64
#  13  heart_disease            630000 non-null  int64
# dtypes: float64(1), int64(13)
# memory usage: 67.3 MB

# %% [markdown]
# ## Create some new features

# %%
features = get_features(train_df)

# %%
def create_some_new_features(passed_df):
    tmp_df = passed_df.copy()
    tmp_df['max_hr_/_thallium'] = tmp_df['max_hr'] / tmp_df['thallium'] + 0.0001
    tmp_df['chest_pain_type_x_slope_of_st'] = tmp_df['chest_pain_type'] * tmp_df['slope_of_st']
    tmp_df['sex_x_chest_pain_type'] = tmp_df['sex'] * tmp_df['chest_pain_type']

    tmp_df['bp_sq'] = tmp_df['bp'] ** 2
    tmp_df['bp_rt'] = np.sqrt(tmp_df['bp'])

    tmp_df['max_hr_sq'] = tmp_df['max_hr'] ** 2
    tmp_df['max_hr_rt'] = np.sqrt(tmp_df['max_hr'])

    tmp_df['cholesterol_sq'] = tmp_df['cholesterol'] ** 2
    tmp_df['cholesterol_rt'] = np.sqrt(tmp_df['cholesterol'])

    tmp_df['st_depression_x_chest_pain_type'] = tmp_df['st_depression'] * tmp_df['chest_pain_type'] 
    # tmp_df['st_depression_x_max_hr'] = tmp_df['st_depression'] * tmp_df['max_hr']
    tmp_df['st_depression_x_age'] = tmp_df['st_depression'] * tmp_df['age']

    # tmp_df['st_depression_/_chest_pain_type'] = tmp_df['st_depression'] / (tmp_df['chest_pain_type']+ 0.0001)
    tmp_df['st_depression_/_max_hr'] = tmp_df['st_depression'] / (tmp_df['max_hr']+ 0.0001)
    # tmp_df['st_depression_/_age'] = tmp_df['st_depression'] / (tmp_df['age']+ 0.0001)

    return tmp_df

# %%
train_df = create_some_new_features(train_df)
test_df = create_some_new_features(test_df)

# %%
orig_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630000 entries, 0 to 629999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       630000 non-null  int64
#  1   Age                      630000 non-null  int64
#  2   Sex                      630000 non-null  int64
#  3   Chest pain type          630000 non-null  int64
#  4   BP                       630000 non-null  int64
#  5   Cholesterol              630000 non-null  int64
#  6   FBS over 120             630000 non-null  int64
#  7   EKG results              630000 non-null  int64
#  8   Max HR                   630000 non-null  int64
#  9   Exercise angina          630000 non-null  int64
#  10  ST depression            630000 non-null  float64
#  11  Slope of ST              630000 non-null  int64
#  12  Number of vessels fluro  630000 non-null  int64
#  13  Thallium                 630000 non-null  int64
#  14  Heart Disease            630000 non-null  object
# dtypes: float64(1), int64(13), object(1)
# memory usage: 72.1+ MB

# %%
train_df_before_ohe = train_df.copy()
test_df_before_ohe = test_df.copy()

ohe_columns = ['thallium', 'chest_pain_type']
train_df = pd.get_dummies(data=train_df, columns=ohe_columns, prefix=ohe_columns, drop_first=False)
# re-add the original integer columns
for col in ohe_columns:
    train_df[col] = train_df_before_ohe[col]

test_df = pd.get_dummies(data=test_df, columns=ohe_columns, prefix=ohe_columns, drop_first=False)
for col in ohe_columns:
    test_df[col] = test_df_before_ohe[col]

# %% [markdown]
# ## Choose target and features

# %%
target = get_target()

# %%
features = get_features(train_df)

# %%
categorical_features = []

# %%
numerical_features = [f for f in features if f not in categorical_features]

# %%
categorical_features
# Out:
# []

# %%
numerical_features
# Out:
# ['age',
#  'sex',
#  'bp',
#  'cholesterol',
#  'fbs_over_120',
#  'ekg_results',
#  'max_hr',
#  'exercise_angina',
#  'st_depression',
#  'slope_of_st',
#  'number_of_vessels_fluro',
#  'max_hr_/_thallium',
#  'chest_pain_type_x_slope_of_st',
#  'sex_x_chest_pain_type',
#  'bp_sq',
#  'bp_rt',
#  'max_hr_sq',
#  'max_hr_rt',
#  'cholesterol_sq',
#  'cholesterol_rt',
#  'st_depression_x_chest_pain_type',
#  'st_depression_x_age',
#  'st_depression_/_max_hr',
#  'thallium_3',
#  'thallium_6',
#  'thallium_7',
#  'chest_pain_type_1',
#  'chest_pain_type_2',
#  'chest_pain_type_3',
#  'chest_pain_type_4',
#  'thallium',
#  'chest_pain_type']

# %%
train_df
# Out:
#         age  sex   bp  cholesterol  fbs_over_120  ekg_results  max_hr  \
# 0        58    1  152          239             0            0     158
# 1        52    1  125          325             0            2     171
# 2        56    0  160          188             0            2     151
# 3        44    0  134          229             0            2     150
# 4        58    1  140          234             0            2     125
# ...     ...  ...  ...          ...           ...          ...     ...
# 629995   56    0  110          226             0            0     132
# 629996   54    1  128          249             1            2     150
# 629997   67    1  130          275             0            0     149
# 629998   52    1  140          199             0            2     157
# 629999   51    0  130          199             0            0     168
#
#         exercise_angina  st_depression  slope_of_st  number_of_vessels_fluro  \
# 0                     1            3.6            2                        2
# 1                     0            0.0            1                        0
# 2                     0            0.0            1                        0
# 3                     0            1.0            2                        0
# 4                     1            3.8            2                        3
# ...                 ...            ...          ...                      ...
# 629995                0            0.0            1                        0
# 629996                0            0.0            2                        0
# 629997                0            0.0            1                        2
# 629998                0            0.0            1                        0
# 629999                0            0.0            1                        0
#
#         heart_disease  max_hr_/_thallium  chest_pain_type_x_slope_of_st  \
# 0                   1          22.571529                              8
# 1                   0          57.000100                              1
# 2                   0          50.333433                              2
# 3                   0          50.000100                              6
# 4                   1          41.666767                              8
# ...               ...                ...                            ...
# 629995              0          18.857243                              1
# 629996              0          50.000100                              8
# 629997              1          21.285814                              4
# 629998              1          26.166767                              4
# 629999              0          56.000100                              2
#
#         sex_x_chest_pain_type  bp_sq      bp_rt  max_hr_sq  max_hr_rt  \
# 0                           4  23104  12.328828      24964  12.569805
# 1                           1  15625  11.180340      29241  13.076697
# 2                           0  25600  12.649111      22801  12.288206
# 3                           0  17956  11.575837      22500  12.247449
# 4                           4  19600  11.832160      15625  11.180340
# ...                       ...    ...        ...        ...        ...
# 629995                      0  12100  10.488088      17424  11.489125
# 629996                      4  16384  11.313708      22500  12.247449
# 629997                      4  16900  11.401754      22201  12.206556
# 629998                      4  19600  11.832160      24649  12.529964
# 629999                      0  16900  11.401754      28224  12.961481
#
#         cholesterol_sq  cholesterol_rt  st_depression_x_chest_pain_type  \
# 0                57121       15.459625                             14.4
# 1               105625       18.027756                              0.0
# 2                35344       13.711309                              0.0
# 3                52441       15.132746                              3.0
# 4                54756       15.297059                             15.2
# ...                ...             ...                              ...
# 629995           51076       15.033296                              0.0
# 629996           62001       15.779734                              0.0
# 629997           75625       16.583124                              0.0
# 629998           39601       14.106736                              0.0
# 629999           39601       14.106736                              0.0
#
#         st_depression_x_age  st_depression_/_max_hr  thallium_3  thallium_6  \
# 0                     208.8                0.022785       False       False
# 1                       0.0                0.000000        True       False
# 2                       0.0                0.000000        True       False
# 3                      44.0                0.006667        True       False
# 4                     220.4                0.030400        True       False
# ...                     ...                     ...         ...         ...
# 629995                  0.0                0.000000       False       False
# 629996                  0.0                0.000000        True       False
# 629997                  0.0                0.000000       False       False
# 629998                  0.0                0.000000       False        True
# 629999                  0.0                0.000000        True       False
#
#         thallium_7  chest_pain_type_1  chest_pain_type_2  chest_pain_type_3  \
# 0             True              False              False              False
# 1            False               True              False              False
# 2            False              False               True              False
# 3            False              False              False               True
# 4            False              False              False              False
# ...            ...                ...                ...                ...
# 629995        True               True              False              False
# 629996       False              False              False              False
# 629997        True              False              False              False
# 629998       False              False              False              False
# 629999       False              False               True              False
#
#         chest_pain_type_4  thallium  chest_pain_type
# 0                    True         7                4
# 1                   False         3                1
# 2                   False         3                2
# 3                   False         3                3
# 4                    True         3                4
# ...                   ...       ...              ...
# 629995              False         7                1
# 629996               True         3                4
# 629997               True         7                4
# 629998               True         6                4
# 629999              False         3                2
#
# [630000 rows x 33 columns]

# %% [markdown]
# ## Encoding

# %%
X_train = train_df[features].copy()
y_train = train_df[target]

X_test = test_df[features].copy()

# %%
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.2, stratify=y_train, random_state=123)

# %% [markdown]
# ## RealMP

# %%
rmp_model = RealMLP_TD_Classifier(device='cuda', random_state=123, n_cv=5, n_refit=0,
                              n_epochs=256, batch_size=256*12, hidden_sizes=[256] * 5,
                              use_ls=False,  # for metrics like AUC / log-loss
                              lr=0.01, verbosity=2)

# %%
rmp_model.fit(X_tr, y_tr, X_val, y_val)
# Out:
# Columns classified as continuous: ['age', 'sex', 'bp', 'cholesterol', 'fbs_over_120', 'ekg_results', 'max_hr', 'exercise_angina', 'st_depression', 'slope_of_st', 'number_of_vessels_fluro', 'max_hr_/_thallium', 'chest_pain_type_x_slope_of_st', 'sex_x_chest_pain_type', 'bp_sq', 'bp_rt', 'max_hr_sq', 'max_hr_rt', 'cholesterol_sq', 'cholesterol_rt', 'st_depression_x_chest_pain_type', 'st_depression_x_age', 'st_depression_/_max_hr', 'thallium', 'chest_pain_type']
# Columns classified as categorical: ['thallium_3', 'thallium_6', 'thallium_7', 'chest_pain_type_1', 'chest_pain_type_2', 'chest_pain_type_3', 'chest_pain_type_4']
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Epoch 1/256: val class_error = 0.117348
# Epoch 2/256: val class_error = 0.116040
# Epoch 3/256: val class_error = 0.116646
# Epoch 4/256: val class_error = 0.115773
# Epoch 5/256: val class_error = 0.115668
# Epoch 6/256: val class_error = 0.115683
# Epoch 7/256: val class_error = 0.115838
# Epoch 8/256: val class_error = 0.115644
# Epoch 9/256: val class_error = 0.116281
# Epoch 10/256: val class_error = 0.115798
# Epoch 11/256: val class_error = 0.115154
# Epoch 12/256: val class_error = 0.114921
# Epoch 13/256: val class_error = 0.114846
# Epoch 14/256: val class_error = 0.115040
# Epoch 15/256: val class_error = 0.114863
# Epoch 16/256: val class_error = 0.114781
# Epoch 17/256: val class_error = 0.114724
# Epoch 18/256: val class_error = 0.114806
# Epoch 19/256: val class_error = 0.114846
# Epoch 20/256: val class_error = 0.114759
# Epoch 21/256: val class_error = 0.114902
# Epoch 22/256: val class_error = 0.115075
# Epoch 23/256: val class_error = 0.115017
# Epoch 24/256: val class_error = 0.115376
# Epoch 25/256: val class_error = 0.115252
# Epoch 26/256: val class_error = 0.115140
# Epoch 27/256: val class_error = 0.115486
# Epoch 28/256: val class_error = 0.115049
# Epoch 29/256: val class_error = 0.115110
# Epoch 30/256: val class_error = 0.115114
# Epoch 31/256: val class_error = 0.115248
# Epoch 32/256: val class_error = 0.115446
# Epoch 33/256: val class_error = 0.115157
# Epoch 34/256: val class_error = 0.114922
# Epoch 35/256: val class_error = 0.115102
# Epoch 36/256: val class_error = 0.115144
# Epoch 37/256: val class_error = 0.115294
# Epoch 38/256: val class_error = 0.115056
# Epoch 39/256: val class_error = 0.114929
# Epoch 40/256: val class_error = 0.115048
# Epoch 41/256: val class_error = 0.114979
# Epoch 42/256: val class_error = 0.115024
# Epoch 43/256: val class_error = 0.114779
# Epoch 44/256: val class_error = 0.115097
# Epoch 45/256: val class_error = 0.114714
# Epoch 46/256: val class_error = 0.114702
# Epoch 47/256: val class_error = 0.114841
# Epoch 48/256: val class_error = 0.114735
# Epoch 49/256: val class_error = 0.114829
# Epoch 50/256: val class_error = 0.114800
# Epoch 51/256: val class_error = 0.114762
# Epoch 52/256: val class_error = 0.114776
# Epoch 53/256: val class_error = 0.114798
# Epoch 54/256: val class_error = 0.114792
# Epoch 55/256: val class_error = 0.114792
# Epoch 56/256: val class_error = 0.114884
# Epoch 57/256: val class_error = 0.114878
# Epoch 58/256: val class_error = 0.114752
# Epoch 59/256: val class_error = 0.114892
# Epoch 60/256: val class_error = 0.115143
# Epoch 61/256: val class_error = 0.115205
# Epoch 62/256: val class_error = 0.115184
# Epoch 63/256: val class_error = 0.115014
# Epoch 64/256: val class_error = 0.115102
# Epoch 65/256: val class_error = 0.115384
# Epoch 66/256: val class_error = 0.115095
# Epoch 67/256: val class_error = 0.115140
# Epoch 68/256: val class_error = 0.115856
# Epoch 69/256: val class_error = 0.115070
# Epoch 70/256: val class_error = 0.115513
# Epoch 71/256: val class_error = 0.115435
# Epoch 72/256: val class_error = 0.115160
# Epoch 73/256: val class_error = 0.115084
# Epoch 74/256: val class_error = 0.115170
# Epoch 75/256: val class_error = 0.115621
# Epoch 76/256: val class_error = 0.115227
# Epoch 77/256: val class_error = 0.115371
# Epoch 78/256: val class_error = 0.115227
# Epoch 79/256: val class_error = 0.114941
# Epoch 80/256: val class_error = 0.115186
# Epoch 81/256: val class_error = 0.114917
# Epoch 82/256: val class_error = 0.115510
# Epoch 83/256: val class_error = 0.115129
# Epoch 84/256: val class_error = 0.115287
# Epoch 85/256: val class_error = 0.114914
# Epoch 86/256: val class_error = 0.114995
# Epoch 87/256: val class_error = 0.114830
# Epoch 88/256: val class_error = 0.114908
# Epoch 89/256: val class_error = 0.115171
# Epoch 90/256: val class_error = 0.115095
# Epoch 91/256: val class_error = 0.114837
# Epoch 92/256: val class_error = 0.114738
# Epoch 93/256: val class_error = 0.115111
# Epoch 94/256: val class_error = 0.114943
# Epoch 95/256: val class_error = 0.114921
# Epoch 96/256: val class_error = 0.114987
# Epoch 97/256: val class_error = 0.114856
# Epoch 98/256: val class_error = 0.114875
# Epoch 99/256: val class_error = 0.114970
# Epoch 100/256: val class_error = 0.115075
# Epoch 101/256: val class_error = 0.114883
# Epoch 102/256: val class_error = 0.114722
# Epoch 103/256: val class_error = 0.114898
# Epoch 104/256: val class_error = 0.114933
# Epoch 105/256: val class_error = 0.115005
# Epoch 106/256: val class_error = 0.114795
# Epoch 107/256: val class_error = 0.114710
# Epoch 108/256: val class_error = 0.114752
# Epoch 109/256: val class_error = 0.114908
# Epoch 110/256: val class_error = 0.114775
# Epoch 111/256: val class_error = 0.114551
# Epoch 112/256: val class_error = 0.114659
# Epoch 113/256: val class_error = 0.114567
# Epoch 114/256: val class_error = 0.114602
# Epoch 115/256: val class_error = 0.114676
# Epoch 116/256: val class_error = 0.114675
# Epoch 117/256: val class_error = 0.114730
# Epoch 118/256: val class_error = 0.114708
# Epoch 119/256: val class_error = 0.114698
# Epoch 120/256: val class_error = 0.114705
# Epoch 121/256: val class_error = 0.114687
# Epoch 122/256: val class_error = 0.114756
# Epoch 123/256: val class_error = 0.114643
# Epoch 124/256: val class_error = 0.114754
# Epoch 125/256: val class_error = 0.114676
# Epoch 126/256: val class_error = 0.114635
# Epoch 127/256: val class_error = 0.114667
# Epoch 128/256: val class_error = 0.114562
# Epoch 129/256: val class_error = 0.114600
# Epoch 130/256: val class_error = 0.114689
# Epoch 131/256: val class_error = 0.114671
# Epoch 132/256: val class_error = 0.114908
# Epoch 133/256: val class_error = 0.114724
# Epoch 134/256: val class_error = 0.114995
# Epoch 135/256: val class_error = 0.114754
# Epoch 136/256: val class_error = 0.114781
# Epoch 137/256: val class_error = 0.114844
# Epoch 138/256: val class_error = 0.114830
# Epoch 139/256: val class_error = 0.114824
# Epoch 140/256: val class_error = 0.114792
# Epoch 141/256: val class_error = 0.114983
# Epoch 142/256: val class_error = 0.115030
# Epoch 143/256: val class_error = 0.115006
# Epoch 144/256: val class_error = 0.115068
# Epoch 145/256: val class_error = 0.114867
# Epoch 146/256: val class_error = 0.114978
# Epoch 147/256: val class_error = 0.114819
# Epoch 148/256: val class_error = 0.115135
# Epoch 149/256: val class_error = 0.114959
# Epoch 150/256: val class_error = 0.115062
# Epoch 151/256: val class_error = 0.114752
# Epoch 152/256: val class_error = 0.114873
# Epoch 153/256: val class_error = 0.114889
# Epoch 154/256: val class_error = 0.115089
# Epoch 155/256: val class_error = 0.115032
# Epoch 156/256: val class_error = 0.114894
# Epoch 157/256: val class_error = 0.114943
# Epoch 158/256: val class_error = 0.114994
# Epoch 159/256: val class_error = 0.115494
# Epoch 160/256: val class_error = 0.114925
# Epoch 161/256: val class_error = 0.114975
# Epoch 162/256: val class_error = 0.115144
# Epoch 163/256: val class_error = 0.114973
# Epoch 164/256: val class_error = 0.115156
# Epoch 165/256: val class_error = 0.114941
# Epoch 166/256: val class_error = 0.114833
# Epoch 167/256: val class_error = 0.114989
# Epoch 168/256: val class_error = 0.114832
# Epoch 169/256: val class_error = 0.115078
# Epoch 170/256: val class_error = 0.115043
# Epoch 171/256: val class_error = 0.115086
# Epoch 172/256: val class_error = 0.114767
# Epoch 173/256: val class_error = 0.114684
# Epoch 174/256: val class_error = 0.115113
# Epoch 175/256: val class_error = 0.114878
# Epoch 176/256: val class_error = 0.115211
# Epoch 177/256: val class_error = 0.115108
# Epoch 178/256: val class_error = 0.114894
# Epoch 179/256: val class_error = 0.114929
# Epoch 180/256: val class_error = 0.114960
# Epoch 181/256: val class_error = 0.114675
# Epoch 182/256: val class_error = 0.115108
# Epoch 183/256: val class_error = 0.114776
# Epoch 184/256: val class_error = 0.114797
# Epoch 185/256: val class_error = 0.114960
# Epoch 186/256: val class_error = 0.114881
# Epoch 187/256: val class_error = 0.114710
# Epoch 188/256: val class_error = 0.115071
# Epoch 189/256: val class_error = 0.114898
# Epoch 190/256: val class_error = 0.114690
# Epoch 191/256: val class_error = 0.114608
# Epoch 192/256: val class_error = 0.114890
# Epoch 193/256: val class_error = 0.114705
# Epoch 194/256: val class_error = 0.114957
# Epoch 195/256: val class_error = 0.114876
# Epoch 196/256: val class_error = 0.114911
# Epoch 197/256: val class_error = 0.115122
# Epoch 198/256: val class_error = 0.114662
# Epoch 199/256: val class_error = 0.114689
# Epoch 200/256: val class_error = 0.114873
# Epoch 201/256: val class_error = 0.114919
# Epoch 202/256: val class_error = 0.114673
# Epoch 203/256: val class_error = 0.114956
# Epoch 204/256: val class_error = 0.114748
# Epoch 205/256: val class_error = 0.114805
# Epoch 206/256: val class_error = 0.115178
# Epoch 207/256: val class_error = 0.114668
# Epoch 208/256: val class_error = 0.114610
# Epoch 209/256: val class_error = 0.114600
# Epoch 210/256: val class_error = 0.114611
# Epoch 211/256: val class_error = 0.114670
# Epoch 212/256: val class_error = 0.114954
# Epoch 213/256: val class_error = 0.114854
# Epoch 214/256: val class_error = 0.114592
# Epoch 215/256: val class_error = 0.114692
# Epoch 216/256: val class_error = 0.114822
# Epoch 217/256: val class_error = 0.114638
# Epoch 218/256: val class_error = 0.114741
# Epoch 219/256: val class_error = 0.114759
# Epoch 220/256: val class_error = 0.114625
# Epoch 221/256: val class_error = 0.114681
# Epoch 222/256: val class_error = 0.114829
# Epoch 223/256: val class_error = 0.114652
# Epoch 224/256: val class_error = 0.114708
# Epoch 225/256: val class_error = 0.114605
# Epoch 226/256: val class_error = 0.114683
# Epoch 227/256: val class_error = 0.114602
# Epoch 228/256: val class_error = 0.114600
# Epoch 229/256: val class_error = 0.114654
# Epoch 230/256: val class_error = 0.114479
# Epoch 231/256: val class_error = 0.114581
# Epoch 232/256: val class_error = 0.114437
# Epoch 233/256: val class_error = 0.114611
# Epoch 234/256: val class_error = 0.114608
# Epoch 235/256: val class_error = 0.114532
# Epoch 236/256: val class_error = 0.114438
# Epoch 237/256: val class_error = 0.114463
# Epoch 238/256: val class_error = 0.114578
# Epoch 239/256: val class_error = 0.114530
# Epoch 240/256: val class_error = 0.114502
# Epoch 241/256: val class_error = 0.114629
# Epoch 242/256: val class_error = 0.114619
# Epoch 243/256: val class_error = 0.114587
# Epoch 244/256: val class_error = 0.114510
# Epoch 245/256: val class_error = 0.114497
# Epoch 246/256: val class_error = 0.114443
# Epoch 247/256: val class_error = 0.114521
# Epoch 248/256: val class_error = 0.114481
# Epoch 249/256: val class_error = 0.114576
# Epoch 250/256: val class_error = 0.114538
# Epoch 251/256: val class_error = 0.114492
# Epoch 252/256: val class_error = 0.114532
# Epoch 253/256: val class_error = 0.114514
# Epoch 254/256: val class_error = 0.114519
# Epoch 255/256: val class_error = 0.114517
# Epoch 256/256: val class_error = 0.114511
# `Trainer.fit` stopped: `max_epochs=256` reached.
# RealMLP_TD_Classifier(batch_size=3072, device='cuda',
#                       hidden_sizes=[256, 256, 256, 256, 256], lr=0.01, n_cv=5,
#                       n_epochs=256, random_state=123, use_ls=False,
#                       verbosity=2)

# %%
rmp_preds = rmp_model.predict_proba(X_train)[:,1]
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]

# %%
print(f"ROC AUC: {roc_auc_score(y_train, rmp_preds):.5f}")
# Out:
# ROC AUC: 0.95362

# %%
preds = rmp_model.predict_proba(X_train)[:,1]
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]

# %%
final_rmp_model = RealMLP_TD_Classifier(device='cuda', random_state=123, n_cv=5, n_refit=0,
                              n_epochs=256, batch_size=256*12, hidden_sizes=[256] * 5,
                              use_ls=False,  # for metrics like AUC / log-loss
                              lr=0.01, verbosity=2)

# %%
_ = final_rmp_model.fit(X_train, y_train)
# Out:
# Columns classified as continuous: ['age', 'sex', 'bp', 'cholesterol', 'fbs_over_120', 'ekg_results', 'max_hr', 'exercise_angina', 'st_depression', 'slope_of_st', 'number_of_vessels_fluro', 'max_hr_/_thallium', 'chest_pain_type_x_slope_of_st', 'sex_x_chest_pain_type', 'bp_sq', 'bp_rt', 'max_hr_sq', 'max_hr_rt', 'cholesterol_sq', 'cholesterol_rt', 'st_depression_x_chest_pain_type', 'st_depression_x_age', 'st_depression_/_max_hr', 'thallium', 'chest_pain_type']
# Columns classified as categorical: ['thallium_3', 'thallium_6', 'thallium_7', 'chest_pain_type_1', 'chest_pain_type_2', 'chest_pain_type_3', 'chest_pain_type_4']
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Epoch 1/256: val class_error = 0.117371
# Epoch 2/256: val class_error = 0.115225
# Epoch 3/256: val class_error = 0.115298
# Epoch 4/256: val class_error = 0.115238
# Epoch 5/256: val class_error = 0.115398
# Epoch 6/256: val class_error = 0.115119
# Epoch 7/256: val class_error = 0.114613
# Epoch 8/256: val class_error = 0.114481
# Epoch 9/256: val class_error = 0.114722
# Epoch 10/256: val class_error = 0.114265
# Epoch 11/256: val class_error = 0.114194
# Epoch 12/256: val class_error = 0.114203
# Epoch 13/256: val class_error = 0.114232
# Epoch 14/256: val class_error = 0.114044
# Epoch 15/256: val class_error = 0.114040
# Epoch 16/256: val class_error = 0.113940
# Epoch 17/256: val class_error = 0.113887
# Epoch 18/256: val class_error = 0.113897
# Epoch 19/256: val class_error = 0.113968
# Epoch 20/256: val class_error = 0.114025
# Epoch 21/256: val class_error = 0.114514
# Epoch 22/256: val class_error = 0.114079
# Epoch 23/256: val class_error = 0.114324
# Epoch 24/256: val class_error = 0.114749
# Epoch 25/256: val class_error = 0.114379
# Epoch 26/256: val class_error = 0.114751
# Epoch 27/256: val class_error = 0.114746
# Epoch 28/256: val class_error = 0.114564
# Epoch 29/256: val class_error = 0.114281
# Epoch 30/256: val class_error = 0.114410
# Epoch 31/256: val class_error = 0.114524
# Epoch 32/256: val class_error = 0.114430
# Epoch 33/256: val class_error = 0.114210
# Epoch 34/256: val class_error = 0.114757
# Epoch 35/256: val class_error = 0.114197
# Epoch 36/256: val class_error = 0.114289
# Epoch 37/256: val class_error = 0.114314
# Epoch 38/256: val class_error = 0.114433
# Epoch 39/256: val class_error = 0.114494
# Epoch 40/256: val class_error = 0.114156
# Epoch 41/256: val class_error = 0.114087
# Epoch 42/256: val class_error = 0.114122
# Epoch 43/256: val class_error = 0.113930
# Epoch 44/256: val class_error = 0.114102
# Epoch 45/256: val class_error = 0.113963
# Epoch 46/256: val class_error = 0.114010
# Epoch 47/256: val class_error = 0.113979
# Epoch 48/256: val class_error = 0.113983
# Epoch 49/256: val class_error = 0.113814
# Epoch 50/256: val class_error = 0.113916
# Epoch 51/256: val class_error = 0.113894
# Epoch 52/256: val class_error = 0.113890
# Epoch 53/256: val class_error = 0.113973
# Epoch 54/256: val class_error = 0.113908
# Epoch 55/256: val class_error = 0.113892
# Epoch 56/256: val class_error = 0.114002
# Epoch 57/256: val class_error = 0.114075
# Epoch 58/256: val class_error = 0.114060
# Epoch 59/256: val class_error = 0.114202
# Epoch 60/256: val class_error = 0.114268
# Epoch 61/256: val class_error = 0.113897
# Epoch 62/256: val class_error = 0.114186
# Epoch 63/256: val class_error = 0.114016
# Epoch 64/256: val class_error = 0.114419
# Epoch 65/256: val class_error = 0.114248
# Epoch 66/256: val class_error = 0.114060
# Epoch 67/256: val class_error = 0.114329
# Epoch 68/256: val class_error = 0.114492
# Epoch 69/256: val class_error = 0.114735
# Epoch 70/256: val class_error = 0.114565
# Epoch 71/256: val class_error = 0.114443
# Epoch 72/256: val class_error = 0.114840
# Epoch 73/256: val class_error = 0.114668
# Epoch 74/256: val class_error = 0.114506
# Epoch 75/256: val class_error = 0.114433
# Epoch 76/256: val class_error = 0.114373
# Epoch 77/256: val class_error = 0.114305
# Epoch 78/256: val class_error = 0.114419
# Epoch 79/256: val class_error = 0.114583
# Epoch 80/256: val class_error = 0.114440
# Epoch 81/256: val class_error = 0.114298
# Epoch 82/256: val class_error = 0.114340
# Epoch 83/256: val class_error = 0.114422
# Epoch 84/256: val class_error = 0.114479
# Epoch 85/256: val class_error = 0.114281
# Epoch 86/256: val class_error = 0.114275
# Epoch 87/256: val class_error = 0.114210
# Epoch 88/256: val class_error = 0.114646
# Epoch 89/256: val class_error = 0.114330
# Epoch 90/256: val class_error = 0.114248
# Epoch 91/256: val class_error = 0.114168
# Epoch 92/256: val class_error = 0.114289
# Epoch 93/256: val class_error = 0.114276
# Epoch 94/256: val class_error = 0.114406
# Epoch 95/256: val class_error = 0.114546
# Epoch 96/256: val class_error = 0.114486
# Epoch 97/256: val class_error = 0.114149
# Epoch 98/256: val class_error = 0.114083
# Epoch 99/256: val class_error = 0.114008
# Epoch 100/256: val class_error = 0.114092
# Epoch 101/256: val class_error = 0.114060
# Epoch 102/256: val class_error = 0.113944
# Epoch 103/256: val class_error = 0.114086
# Epoch 104/256: val class_error = 0.114243
# Epoch 105/256: val class_error = 0.113914
# Epoch 106/256: val class_error = 0.114037
# Epoch 107/256: val class_error = 0.114005
# Epoch 108/256: val class_error = 0.113992
# Epoch 109/256: val class_error = 0.113994
# Epoch 110/256: val class_error = 0.113949
# Epoch 111/256: val class_error = 0.113835
# Epoch 112/256: val class_error = 0.113770
# Epoch 113/256: val class_error = 0.113919
# Epoch 114/256: val class_error = 0.113863
# Epoch 115/256: val class_error = 0.113875
# Epoch 116/256: val class_error = 0.113803
# Epoch 117/256: val class_error = 0.113862
# Epoch 118/256: val class_error = 0.113894
# Epoch 119/256: val class_error = 0.113889
# Epoch 120/256: val class_error = 0.113892
# Epoch 121/256: val class_error = 0.113878
# Epoch 122/256: val class_error = 0.113875
# Epoch 123/256: val class_error = 0.113876
# Epoch 124/256: val class_error = 0.113911
# Epoch 125/256: val class_error = 0.113917
# Epoch 126/256: val class_error = 0.113967
# Epoch 127/256: val class_error = 0.113916
# Epoch 128/256: val class_error = 0.113949
# Epoch 129/256: val class_error = 0.113870
# Epoch 130/256: val class_error = 0.114087
# Epoch 131/256: val class_error = 0.114044
# Epoch 132/256: val class_error = 0.113994
# Epoch 133/256: val class_error = 0.113889
# Epoch 134/256: val class_error = 0.113954
# Epoch 135/256: val class_error = 0.113933
# Epoch 136/256: val class_error = 0.114319
# Epoch 137/256: val class_error = 0.113883
# Epoch 138/256: val class_error = 0.114171
# Epoch 139/256: val class_error = 0.114087
# Epoch 140/256: val class_error = 0.114303
# Epoch 141/256: val class_error = 0.113963
# Epoch 142/256: val class_error = 0.114132
# Epoch 143/256: val class_error = 0.113986
# Epoch 144/256: val class_error = 0.113994
# Epoch 145/256: val class_error = 0.114346
# Epoch 146/256: val class_error = 0.114024
# Epoch 147/256: val class_error = 0.114132
# Epoch 148/256: val class_error = 0.114187
# Epoch 149/256: val class_error = 0.114098
# Epoch 150/256: val class_error = 0.114222
# Epoch 151/256: val class_error = 0.114497
# Epoch 152/256: val class_error = 0.114306
# Epoch 153/256: val class_error = 0.113954
# Epoch 154/256: val class_error = 0.114227
# Epoch 155/256: val class_error = 0.114225
# Epoch 156/256: val class_error = 0.114168
# Epoch 157/256: val class_error = 0.114548
# Epoch 158/256: val class_error = 0.114210
# Epoch 159/256: val class_error = 0.114217
# Epoch 160/256: val class_error = 0.114060
# Epoch 161/256: val class_error = 0.114273
# Epoch 162/256: val class_error = 0.114424
# Epoch 163/256: val class_error = 0.114410
# Epoch 164/256: val class_error = 0.114324
# Epoch 165/256: val class_error = 0.114173
# Epoch 166/256: val class_error = 0.114202
# Epoch 167/256: val class_error = 0.114037
# Epoch 168/256: val class_error = 0.114070
# Epoch 169/256: val class_error = 0.114283
# Epoch 170/256: val class_error = 0.114465
# Epoch 171/256: val class_error = 0.114197
# Epoch 172/256: val class_error = 0.114157
# Epoch 173/256: val class_error = 0.114432
# Epoch 174/256: val class_error = 0.114254
# Epoch 175/256: val class_error = 0.114414
# Epoch 176/256: val class_error = 0.114467
# Epoch 177/256: val class_error = 0.114133
# Epoch 178/256: val class_error = 0.114303
# Epoch 179/256: val class_error = 0.114119
# Epoch 180/256: val class_error = 0.114254
# Epoch 181/256: val class_error = 0.113986
# Epoch 182/256: val class_error = 0.114452
# Epoch 183/256: val class_error = 0.114138
# Epoch 184/256: val class_error = 0.114325
# Epoch 185/256: val class_error = 0.114171
# Epoch 186/256: val class_error = 0.114065
# Epoch 187/256: val class_error = 0.114444
# Epoch 188/256: val class_error = 0.114049
# Epoch 189/256: val class_error = 0.114203
# Epoch 190/256: val class_error = 0.114289
# Epoch 191/256: val class_error = 0.114384
# Epoch 192/256: val class_error = 0.114206
# Epoch 193/256: val class_error = 0.114270
# Epoch 194/256: val class_error = 0.114208
# Epoch 195/256: val class_error = 0.114363
# Epoch 196/256: val class_error = 0.114106
# Epoch 197/256: val class_error = 0.114097
# Epoch 198/256: val class_error = 0.114144
# Epoch 199/256: val class_error = 0.114610
# Epoch 200/256: val class_error = 0.114111
# Epoch 201/256: val class_error = 0.114073
# Epoch 202/256: val class_error = 0.114316
# Epoch 203/256: val class_error = 0.114208
# Epoch 204/256: val class_error = 0.114049
# Epoch 205/256: val class_error = 0.114046
# Epoch 206/256: val class_error = 0.114114
# Epoch 207/256: val class_error = 0.114171
# Epoch 208/256: val class_error = 0.114184
# Epoch 209/256: val class_error = 0.114022
# Epoch 210/256: val class_error = 0.113935
# Epoch 211/256: val class_error = 0.114583
# Epoch 212/256: val class_error = 0.113987
# Epoch 213/256: val class_error = 0.114025
# Epoch 214/256: val class_error = 0.114213
# Epoch 215/256: val class_error = 0.114056
# Epoch 216/256: val class_error = 0.113989
# Epoch 217/256: val class_error = 0.113876
# Epoch 218/256: val class_error = 0.114037
# Epoch 219/256: val class_error = 0.114002
# Epoch 220/256: val class_error = 0.114075
# Epoch 221/256: val class_error = 0.113979
# Epoch 222/256: val class_error = 0.113913
# Epoch 223/256: val class_error = 0.113879
# Epoch 224/256: val class_error = 0.113944
# Epoch 225/256: val class_error = 0.113992
# Epoch 226/256: val class_error = 0.113968
# Epoch 227/256: val class_error = 0.114010
# Epoch 228/256: val class_error = 0.113962
# Epoch 229/256: val class_error = 0.113994
# Epoch 230/256: val class_error = 0.113913
# Epoch 231/256: val class_error = 0.113867
# Epoch 232/256: val class_error = 0.113963
# Epoch 233/256: val class_error = 0.113814
# Epoch 234/256: val class_error = 0.113778
# Epoch 235/256: val class_error = 0.113833
# Epoch 236/256: val class_error = 0.113943
# Epoch 237/256: val class_error = 0.113887
# Epoch 238/256: val class_error = 0.113921
# Epoch 239/256: val class_error = 0.113965
# Epoch 240/256: val class_error = 0.113700
# Epoch 241/256: val class_error = 0.113846
# Epoch 242/256: val class_error = 0.113848
# Epoch 243/256: val class_error = 0.113811
# Epoch 244/256: val class_error = 0.113786
# Epoch 245/256: val class_error = 0.113895
# Epoch 246/256: val class_error = 0.113840
# Epoch 247/256: val class_error = 0.113789
# Epoch 248/256: val class_error = 0.113859
# Epoch 249/256: val class_error = 0.113824
# Epoch 250/256: val class_error = 0.113814
# Epoch 251/256: val class_error = 0.113803
# Epoch 252/256: val class_error = 0.113824
# Epoch 253/256: val class_error = 0.113821
# Epoch 254/256: val class_error = 0.113830
# Epoch 255/256: val class_error = 0.113829
# Epoch 256/256: val class_error = 0.113825
# `Trainer.fit` stopped: `max_epochs=256` reached.

# %%
# rmp_scores = cross_val_score(
#     final_rmp_model, 
#     X_train, 
#     y_train, 
#     cv=10, 
#     scoring='roc_auc'
# )

# %%
# print(f"ROC AUC: {roc_auc_score(y_train, preds):.5f}")

# %% [markdown]
# ## Run Predictions

# %%
final_preds = np.zeros(len(X_test))

final_preds = final_rmp_model.predict_proba(X_test)[:,1]
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]

# %% [markdown]
# ## Prepare Submission

# %%
# Create submission
submission_df = pd.DataFrame({
  'id': orig_test_df['id'],
  'Heart Disease': final_preds
})

# %%
last_submission = pd.read_csv(find_last_submission_file())

# %%
# submission_df.to_csv('./archive/submission_01.csv', index=False)

# %%
submission_df.head()
# Out:
#        id  Heart Disease
# 0  630000       0.919297
# 1  630001       0.004722
# 2  630002       0.991301
# 3  630003       0.003309
# 4  630004       0.319843

# %%
sns.histplot(submission_df['Heart Disease'])
# Out:
# <Axes: xlabel='Heart Disease', ylabel='Count'>

# %%
if np.allclose(last_submission['Heart Disease'], submission_df['Heart Disease']):
    # they are the same, don't same
    print('skipping save')
else:
    submission_df.to_csv(find_next_submission_file(), index=False)
    print('saving file')
# Out:
# saving file
